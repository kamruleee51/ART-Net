# %% [markdown]
# **Detection, Segmentation, and 3D Pose Estimation of Surgical Tools Using Deep Convolutional Neural Networks and Algebraic Geometry**
#
# Article link: https://www.sciencedirect.com/science/article/abs/pii/S1361841521000402
#
# * This code is dedicated to the evaluations of the proposed ART-Net. There are several sub-networks of the complete ART-Net, which are: <br>
# &emsp; &emsp; &emsp; 1. Detection sub-network for the tool presence identification.  <br>
# &emsp; &emsp; &emsp; 2. Segmentation sub-network for getting the surgical instrument masks.  <br>
# &emsp; &emsp; &emsp; 3. Regression sub-network-1 for edgeLine (tool boundary) extraction.  <br>
# &emsp; &emsp; &emsp; 4. Regression sub-network-2 for midLine extraction. <br>
# &emsp; &emsp; &emsp; 5. Regression sub-network-3 for toolTip extraction.  <br>
#
#
#
#
#
# * **Input:** The output predictions of each sub-network.
#
# * **Output:** The quantitative metrics for that sub-network.
#
#
#
# * This code is written by
#         ** Md. Kamrul Hasan
#         ** Medical Imaging and Applications (MAIA)
#         ** Erasmus Scholar [2017-2019]
#         ** Contact: kamruleeekuet@gmail.com

# %% [markdown]
#  ## Import packages

# %%
import numpy as np 
import os
import glob
import cv2
import glob
import itertools
from skimage.morphology import skeletonize
import skimage.io as io
import skimage.transform as trans
import matplotlib.pyplot as plt
from math import atan2,degrees, atan
% matplotlib inline
from mpl_toolkits.mplot3d import Axes3D
from skimage.morphology import skeletonize
from skimage.transform import hough_line, hough_line_peaks, probabilistic_hough_line
from matplotlib import cm
from shapely.geometry import LineString
from shapely.geometry import Point
from sympy import *
import math
from sympy.geometry import *
from skimage.measure import label, regionprops
from scipy.spatial import distance
from skimage.morphology import disk
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import jaccard_similarity_score
from sklearn.metrics import precision_score, accuracy_score, roc_curve, auc

# %% [markdown]
# ## Define utility functions

# %%
def Angular_Displacement(height, width, L1x1, L1y1, L1x2, L1y2, L2x1, L2y1, L2x2, L2y2):
    '''
    This code is for calculating Angular Displacement between a pair of lines.
    The predicted edge and mid line features can be evaluated quantitatively using the mean angular 
    displacement (mAD) error from the center of the image frame between the true andpredicted line.
    Angular displacement is calculated by the arc length distance between true point and predicted point.
    More details explanations of this metric see the paper please. 
    
    Input Arguments: 
        height = Height of the Image
        width  = Width of the Image
        L1x1 =  Initial X co-ordinate of the first line
        L1y1 =  Initial Y co-ordinate of the first line
        L1x2 =  Final X co-ordinate of the first line
        L1y2 =  Final Y co-ordinate of the first line
        L2x1 =  Initial X co-ordinate of the second line
        L2y1 =  Initial Y co-ordinate of the second line
        L2x2 =  Final X co-ordinate of the second line
        L2y2 =  Final Y co-ordinate of the second line
        
    Output Arguments:  
    
        AngularDisplacement: The average Angular Displacement of left and right side Displacement.
        
    Author: Md. Kamrul Hasan, 
        Erasmus Scholar on Medical Imaging and Application (MAIA)
        E-mail: kamruleeekuet@gmail.com
        
    '''

    center_x = int(height/2)
    center_y = int(width/2)
    centerPoint = Point(center_x,center_y)
    radius = np.sqrt((center_x)**2+(center_y)**2)

    circle = Circle(centerPoint, radius)

    lineApprox = Line((L1x1,L1y1),(L1x2,L1y2))
    lineTrue = Line((L2x1,L2y1),(L2x2,L2y2))

    intersectionApprox= intersection(circle, lineApprox)
    intersectionTrue= intersection(circle, lineTrue)

    intXY1P = intersectionApprox[0].evalf()
    X_P_1 = intXY1P.x
    Y_P_1 = intXY1P.y
#         print(X_P_1)
#         print(Y_P_1)

    intXY2P = intersectionApprox[1].evalf()
    X_P_2 = intXY2P.x
    Y_P_2 = intXY2P.y
#         print(X_P_2)
#         print(Y_P_2)


    intXY1G = intersectionTrue[0].evalf()
    X_G_1 = intXY1G.x
    Y_G_1 = intXY1G.y
#         print(X_G_1)
#         print(Y_G_1)


    intXY2G = intersectionTrue[1].evalf()
    X_G_2 = intXY2G.x
    Y_G_2 = intXY2G.y
#         print(X_G_2)
#         print(Y_G_2)

    slope1_P, intercept=slope_intercept(X_P_1, Y_P_1, center_x, center_y)
    slope1_G, intercept=slope_intercept(X_G_1, Y_G_1, center_x, center_y)

    slope2_P, intercept=slope_intercept(X_P_2, Y_P_2, center_x, center_y)
    slope2_G, intercept=slope_intercept(X_G_2, Y_G_2, center_x, center_y)

#         print(slope1_P)
#         print(slope1_G)
#         print(slope2_P)
#         print(slope2_G)

    theta_1=atan(abs((slope1_P-slope1_G)/(1+slope1_G*slope1_P)))
    theta_2=atan(abs((slope2_P-slope2_G)/(1+slope2_G*slope2_P)))
    
    AngularDisplacement=(theta_1+theta_2)/2
    
    return AngularDisplacement



def Performance_Metrics(y_true, y_pred):
    ''' 
    The Dice similarity coefficient (DSC) is a statistical validation metric for the image
    segmentations and determines the spatial overlap accuracy of the segmentation. It also 
    same as F1-score. 
    
    The Intersection over Union (IoU) also referred to as the Jaccard index (JI), is essentially
    a method to quantify the percent overlap between the GT mask and prediction output.
    This metric is closely related to the DSC. The IoU metric measures the number of pixels
    common between the target and prediction masks divided by the total number of pixels present
    across both masks.
    
    Mathematically, they are related as follows:
    IoU = DSC/(2-DSC) or DSC = 2*IoU/(IoU+1)
    
    The Sensitivity also called the true positive rate, the recall, or probability of detection that 
    measures the proportion of actual positives that are correctly identified as such class 
    (e.g., the percentage of sick people who are correctly identified as having the condition).
    
    The Specificity also called the true negative rate measures the proportion of actual negatives that
    are correctly identified as such class. (e.g., the percentage of healthy people who are correctly
    identified as not having the condition).
    
  
    Input Arguments: 
        y_true: True Labels of the 2D images so called ground truth (GT).
        y_pred: Predicted Labels of the 2D images so called Predicted/ segmented Mask.
        
    Output Arguments: 
        dsc: The DSC between y_true and y_pred
        iou: The IoU between y_true and y_pred
        accuracy: The accuracy of pixels clasification.
        sensitivity: The accuracy of foreground pixels clasification.
        specificity: The accuracy of background pixels clasification.
        balancedAccuracy: The balanced accuracy of both foreground & background pixels clasification.
        
    Author: Md. Kamrul Hasan, 
            Erasmus Scholar on Medical Imaging and Application (MAIA)
            E-mail: kamruleeekuet@gmail.com

    '''
    if y_true.shape != y_pred.shape:
        raise ValueError("Shape mismatch!! y_true and y_pred must have the same shape.")

    y_true_f = (y_true/y_true.max()).flatten()
    y_pred_f = (y_pred/y_pred.max()).flatten()
    
    intersection = np.sum(y_true_f * y_pred_f)
    
    dsc = (2. * intersection ) / (np.sum(y_true_f) + np.sum(y_pred_f))
    iou = (intersection) / (np.sum(y_true_f) + np.sum(y_pred_f)-intersection)
    
    y_true = np.asarray(y_true).astype(np.bool)
    y_pred = np.asarray(y_pred).astype(np.bool)

        
    y_true=y_true.flatten()
    y_pred=y_pred.flatten()
    
    tn, fp, fn, tp = confusion_matrix(y_true, y_pred).ravel()
    accuracy = (tn+tp)/(tn+fp+fn+tp)
    sensitivity = (tp)/(fn+tp)
    specificity = (tn)/(tn+fp)
    balancedAccuracy = (sensitivity+specificity)/2

    
    return dsc, iou, accuracy, sensitivity, specificity, balancedAccuracy



def slope_intercept(xi, yi, xf, yf):
    '''
    This function is dedicated for calculating the slope of the line. 
    
    Input Arguments: 
         xi: The initial X co-ordinate
         yi: The initial Y co-ordinate
         xf: The final X co-ordinate
         yf: The final Y co-ordinate
         
    Output Arguments:
        slope: Slope of the st. line connecting those two points
        intercept: The intersecting length from Y-axis
         
    Author: Md. Kamrul Hasan, 
        Erasmus Scholar on Medical Imaging and Application (MAIA)
        E-mail: kamruleeekuet@gmail.com
        
    '''
    
    slope = (yf - yi) / (xf - xi)
    intercept = yi - slope * xi 
    
    return slope,intercept

# %% [markdown]
# ## Evaluations of Segmentation Sub-network

# %%
CurrentDirectory=os.getcwd()
PredictionPath = CurrentDirectory+'/Mask_V1/'
Prediction = glob.glob(PredictionPath+"*.png")
Prediction.sort()
# print(len(Prediction))

OriginalmaskGT = glob.glob(CurrentDirectory+'/Test_Tool_GT/'+"*.png")
OriginalmaskGT.sort()
# print(len(OriginalmaskGT))

OriginalImage = glob.glob(CurrentDirectory+'/TestImage/'+"*.png")
OriginalImage.sort()
# print(len(OriginalImage))

masksavePath = CurrentDirectory+'/Segmentation/'

i=0

dice=[]
sensitivity=[]
specificity=[]
accuracy = []
BalancedAccuracy=[]
IoU=[]

for Pred in Prediction:
    
    filename, file_extension = os.path.splitext(Pred) 
    
    if filename[-4:]=='tool':
        #----------------------------------Read the Prediction from SIMO------------------------------
        imgPred = cv2.imread(Pred,0)
        
        # Apply the threshold since output was sigmoid activations of segmentation sub-network
        threshold = 30
        imgPred[imgPred<threshold] = 0
        imgPred[imgPred>=threshold] = 255
        
        #--------------------------------Read Original Image with Mask GT----------------------------
        orimg = cv2.imread(OriginalImage[i],-1)
        orimg = cv2.resize(orimg,(256,192))
        
        truemask = cv2.imread(OriginalmaskGT[i],0)
        truemask = cv2.resize(truemask,(256,192))
        i=i+1
        
        #-------------------------------Overlay with original Image------------------------------------       
        temp = cv2.merge((imgPred, imgPred, imgPred))
        temp [:,:,0]=0
        temp [:,:,2]=0       

        overlay = cv2.addWeighted(temp, 0.5, orimg, 0.8, 0)
        
     
        # Call the Performance Evaluation functions by passing predicted and true mask
        dsc, iou, acc, sen, spe, bAcc = Performance_Metrics(imgPred, truemask)

        dice.append(dsc)
        IoU.append(iou)
        accuracy.append(acc)
        sensitivity.append(sen)
        specificity.append(spe)
        BalancedAccuracy.append(bAcc)
        
        font                   = cv2.FONT_HERSHEY_SIMPLEX
        bottomLeftCornerOfText = (80,185)
        fontScale              = 1
        fontColor              = (255,255,255)
        lineType               = 2
        

        cv2.putText(overlay, str(round(dsc,4)), 
            bottomLeftCornerOfText, 
            font, 
            fontScale,
            fontColor,
            lineType)
        
        savelinePath=masksavePath+'ImgID_'+filename[-8:]+'_Overlay_with_OrgImg.png'
        cv2.imwrite(savelinePath, overlay)  
        print('ImageID: '+ filename[-8:-5]+'. Dice co-efficient: '+ str(dsc)
              + '  Balanced Accuracy: ' + str(bAcc))
        
print()
print('-----------------------Final Segmentation metrics are as follows:---------------------------')
print("DSC = %0.4f (+/-%0.04f)" % (np.mean(dice)*100, np.std(dice)*100))
print("Sensitivity = %0.4f (+/-%0.04f)" % (np.mean(sensitivity)*100, np.std(sensitivity)*100))
print("Specificity = %0.4f (+/-%0.04f)" % (np.mean(specificity)*100, np.std(specificity)*100))
print("Accuracy = %0.8f (+/-%0.04f)" % (np.mean(accuracy)*100, np.std(accuracy)*100))
print("IoU = %0.4f (+/-%0.04f)" % (np.mean(IoU)*100, np.std(IoU)*100))
print("Balanced Accuracy = %0.4f (+/-%0.04f)" % (np.mean(BalancedAccuracy)*100, np.std(BalancedAccuracy)*100))
# Out:
# ImageID: 011. Dice co-efficient: 0.8947923197943348  Balanced Accuracy: 0.9671406817990115
# ImageID: 015. Dice co-efficient: 0.9373013006956873  Balanced Accuracy: 0.9616706615020947
# ImageID: 017. Dice co-efficient: 0.9683049175948321  Balanced Accuracy: 0.9878567825680333
# ImageID: 020. Dice co-efficient: 0.9775013781128693  Balanced Accuracy: 0.9869846389921632
# ImageID: 037. Dice co-efficient: 0.976922065171593  Balanced Accuracy: 0.980856927078793
# ImageID: 046. Dice co-efficient: 0.9670989173991883  Balanced Accuracy: 0.9813949857299211
# ImageID: 062. Dice co-efficient: 0.9703446158678937  Balanced Accuracy: 0.9823543498609828
# ImageID: 070. Dice co-efficient: 0.9619752018290765  Balanced Accuracy: 0.9734524616523708
# ImageID: 075. Dice co-efficient: 0.9480056449747392  Balanced Accuracy: 0.9839093406557546
# ImageID: 079. Dice co-efficient: 0.9312343646057728  Balanced Accuracy: 0.9814958859975758
# ImageID: 083. Dice co-efficient: 0.9369814074393965  Balanced Accuracy: 0.9612475411706278
# ImageID: 084. Dice co-efficient: 0.9230009697195354  Balanced Accuracy: 0.9501896801862653
# ImageID: 085. Dice co-efficient: 0.9432105854482861  Balanced Accuracy: 0.9633082564435372
# ImageID: 091. Dice co-efficient: 0.8740785430599454  Balanced Accuracy: 0.9750874382902333
# ImageID: 108. Dice co-efficient: 0.948534922936618  Balanced Accuracy: 0.985760279870438
# ImageID: 110. Dice co-efficient: 0.9758213750741197  Balanced Accuracy: 0.9871344548732494
# ImageID: 114. Dice co-efficient: 0.9658144190315741  Balanced Accuracy: 0.984699848556157
# ImageID: 125. Dice co-efficient: 0.9549760322311228  Balanced Accuracy: 0.9845286557444419
# ImageID: 128. Dice co-efficient: 0.9286497313409643  Balanced Accuracy: 0.9472599243248117
# ImageID: 135. Dice co-efficient: 0.9191567709293073  Balanced Accuracy: 0.9472464945947934
# ImageID: 155. Dice co-efficient: 0.9467429683705814  Balanced Accuracy: 0.9734162571503868
# ImageID: 160. Dice co-efficient: 0.9409522102987344  Balanced Accuracy: 0.9627409268790423
# ImageID: 161. Dice co-efficient: 0.93009998689407  Balanced Accuracy: 0.9461562370859806
# ImageID: 162. Dice co-efficient: 0.9722464178498581  Balanced Accuracy: 0.9812841589445249
# ImageID: 169. Dice co-efficient: 0.957047548929835  Balanced Accuracy: 0.9812012389315591
# ImageID: 171. Dice co-efficient: 0.9577060186110754  Balanced Accuracy: 0.9774300327596095
# ImageID: 173. Dice co-efficient: 0.7112620523576741  Balanced Accuracy: 0.8018418898030157
# ImageID: 187. Dice co-efficient: 0.8895696444675547  Balanced Accuracy: 0.9316488674484362
# ImageID: 188. Dice co-efficient: 0.9437700591281644  Balanced Accuracy: 0.9856013457750874
# ImageID: 197. Dice co-efficient: 0.9610044004456061  Balanced Accuracy: 0.9749928828989515
# ImageID: 198. Dice co-efficient: 0.9279385658401009  Balanced Accuracy: 0.9433135494656089
# ImageID: 199. Dice co-efficient: 0.9156153810928254  Balanced Accuracy: 0.9563823181213974
# ImageID: 210. Dice co-efficient: 0.9714655589371555  Balanced Accuracy: 0.9868461182196546
# ImageID: 213. Dice co-efficient: 0.9377241898384845  Balanced Accuracy: 0.9809322399308411
# ImageID: 214. Dice co-efficient: 0.9528173130794836  Balanced Accuracy: 0.9849234420571489
# ImageID: 215. Dice co-efficient: 0.9751745437573816  Balanced Accuracy: 0.9821806018747077
# ImageID: 223. Dice co-efficient: 0.9705672817238007  Balanced Accuracy: 0.9864007296777859
# ImageID: 233. Dice co-efficient: 0.981309619552474  Balanced Accuracy: 0.9870685567262997
# ImageID: 236. Dice co-efficient: 0.9785703539301238  Balanced Accuracy: 0.987179241675773
# ImageID: 238. Dice co-efficient: 0.9248136742714723  Balanced Accuracy: 0.9807451247338591
# ImageID: 239. Dice co-efficient: 0.9413632944491541  Balanced Accuracy: 0.9547842947941991
# ImageID: 241. Dice co-efficient: 0.9609207361907883  Balanced Accuracy: 0.9717720478311167
# ImageID: 245. Dice co-efficient: 0.9422143712272264  Balanced Accuracy: 0.9740532271404336
# ImageID: 250. Dice co-efficient: 0.9522941597547502  Balanced Accuracy: 0.9747062357862204
# ImageID: 253. Dice co-efficient: 0.9433839420287362  Balanced Accuracy: 0.9680604184819561
# ImageID: 254. Dice co-efficient: 0.9385458534360569  Balanced Accuracy: 0.9727154809532625
# ImageID: 260. Dice co-efficient: 0.9781650400082337  Balanced Accuracy: 0.9937651451330778
# ImageID: 261. Dice co-efficient: 0.972521150649017  Balanced Accuracy: 0.9862425408752871
# ImageID: 264. Dice co-efficient: 0.9445650762131595  Balanced Accuracy: 0.9838287153523795
# ImageID: 266. Dice co-efficient: 0.9446273212665185  Balanced Accuracy: 0.9641440590879897
# ImageID: 271. Dice co-efficient: 0.9684738023537629  Balanced Accuracy: 0.9832666746320351
# ImageID: 272. Dice co-efficient: 0.928475111073691  Balanced Accuracy: 0.9692121192259351
# ImageID: 273. Dice co-efficient: 0.9632308317504874  Balanced Accuracy: 0.9797333767583485
# ImageID: 275. Dice co-efficient: 0.9735957197701963  Balanced Accuracy: 0.9853238595403984
# ImageID: 281. Dice co-efficient: 0.9501259360546108  Balanced Accuracy: 0.9580494376359907
# ImageID: 291. Dice co-efficient: 0.9614935521152262  Balanced Accuracy: 0.9795363961878526
# ImageID: 301. Dice co-efficient: 0.9621215753657487  Balanced Accuracy: 0.9901681677950178
# ImageID: 302. Dice co-efficient: 0.9641498468117264  Balanced Accuracy: 0.969329550792775
# ImageID: 309. Dice co-efficient: 0.9791225185373893  Balanced Accuracy: 0.9864226279274498
# ImageID: 310. Dice co-efficient: 0.9331341405799469  Balanced Accuracy: 0.9818759103492158
# ImageID: 315. Dice co-efficient: 0.9428136739100188  Balanced Accuracy: 0.9795515465717429
# ImageID: 316. Dice co-efficient: 0.954051837534872  Balanced Accuracy: 0.9716110702162022
# ImageID: 319. Dice co-efficient: 0.9375099861289554  Balanced Accuracy: 0.9674497422016974
# ImageID: 321. Dice co-efficient: 0.9455233214960901  Balanced Accuracy: 0.9677111951678425
# ImageID: 324. Dice co-efficient: 0.9523174978909265  Balanced Accuracy: 0.9814791287057587
# ImageID: 328. Dice co-efficient: 0.9607643108217069  Balanced Accuracy: 0.9830354526861893
# ImageID: 329. Dice co-efficient: 0.8553404687996359  Balanced Accuracy: 0.9553574094585724
# ImageID: 331. Dice co-efficient: 0.9569470762620977  Balanced Accuracy: 0.9692510394524771
# ImageID: 339. Dice co-efficient: 0.8652149799163323  Balanced Accuracy: 0.9674656282264451
# ImageID: 343. Dice co-efficient: 0.9337054734548367  Balanced Accuracy: 0.9739817364467678
# ImageID: 345. Dice co-efficient: 0.9485703745367018  Balanced Accuracy: 0.9704150219830788
# ImageID: 347. Dice co-efficient: 0.9146196095117567  Balanced Accuracy: 0.9530531828799824
# ImageID: 351. Dice co-efficient: 0.9319243717573599  Balanced Accuracy: 0.9679004148959716
# ImageID: 360. Dice co-efficient: 0.9402257784957204  Balanced Accuracy: 0.9617057809341609
# ImageID: 362. Dice co-efficient: 0.9524375107457277  Balanced Accuracy: 0.9817502927790165
# ImageID: 368. Dice co-efficient: 0.9583124753749199  Balanced Accuracy: 0.9751604205973956
# ImageID: 372. Dice co-efficient: 0.9637874074843352  Balanced Accuracy: 0.9782001212599853
# ImageID: 373. Dice co-efficient: 0.9597903236121585  Balanced Accuracy: 0.9757114651416122
# ImageID: 376. Dice co-efficient: 0.922685861610848  Balanced Accuracy: 0.949344623796819
# ImageID: 379. Dice co-efficient: 0.9436662282712032  Balanced Accuracy: 0.9797327415827461
# ImageID: 393. Dice co-efficient: 0.7813494205090116  Balanced Accuracy: 0.9781812490424009
# ImageID: 399. Dice co-efficient: 0.9565077762266964  Balanced Accuracy: 0.9711671119056515
# ImageID: 400. Dice co-efficient: 0.9309836669532113  Balanced Accuracy: 0.9568692645877388
# ImageID: 406. Dice co-efficient: 0.9680790002069743  Balanced Accuracy: 0.9818812202209396
# ImageID: 408. Dice co-efficient: 0.9346045871073678  Balanced Accuracy: 0.9765304804718895
# ImageID: 409. Dice co-efficient: 0.8970992845089676  Balanced Accuracy: 0.9591428016799746
# ImageID: 410. Dice co-efficient: 0.9522184609257618  Balanced Accuracy: 0.9681157036158807
# ImageID: 412. Dice co-efficient: 0.9332014090467478  Balanced Accuracy: 0.9422309724555291
# ImageID: 418. Dice co-efficient: 0.9491690703236471  Balanced Accuracy: 0.9648749591052757
# ImageID: 426. Dice co-efficient: 0.9749886446637646  Balanced Accuracy: 0.9836081604506091
# ImageID: 430. Dice co-efficient: 0.9749505511568863  Balanced Accuracy: 0.9795942740053769
# ImageID: 431. Dice co-efficient: 0.9806123749601594  Balanced Accuracy: 0.9877580565504016
# ImageID: 435. Dice co-efficient: 0.9696373718335533  Balanced Accuracy: 0.9826224121750671
# ImageID: 436. Dice co-efficient: 0.9698868867957716  Balanced Accuracy: 0.9923931532152155
# ImageID: 438. Dice co-efficient: 0.9092314348119888  Balanced Accuracy: 0.9425072762554466
# ImageID: 440. Dice co-efficient: 0.957950397714946  Balanced Accuracy: 0.9745873839758079
# ImageID: 442. Dice co-efficient: 0.948413343706526  Balanced Accuracy: 0.9740548912291607
# ImageID: 454. Dice co-efficient: 0.9508491437769201  Balanced Accuracy: 0.9814892285455026
# ImageID: 456. Dice co-efficient: 0.9512922029401001  Balanced Accuracy: 0.9855570279362702
# ImageID: 471. Dice co-efficient: 0.9660831889663699  Balanced Accuracy: 0.9934190947277666
# ImageID: 474. Dice co-efficient: 0.9755963925468006  Balanced Accuracy: 0.989361014465673
# ImageID: 483. Dice co-efficient: 0.9231967927352013  Balanced Accuracy: 0.9804689899708154
# ImageID: 490. Dice co-efficient: 0.9684719063759413  Balanced Accuracy: 0.9820706613645425
# ImageID: 495. Dice co-efficient: 0.9530431375916882  Balanced Accuracy: 0.9674002110187374
# ImageID: 500. Dice co-efficient: 0.9019195639550899  Balanced Accuracy: 0.9449085707184595
# ImageID: 502. Dice co-efficient: 0.953389937699934  Balanced Accuracy: 0.9935629899467306
# ImageID: 504. Dice co-efficient: 0.9487009512855002  Balanced Accuracy: 0.9683656423926118
# ImageID: 507. Dice co-efficient: 0.9672705707931801  Balanced Accuracy: 0.9841740439711899
# ImageID: 512. Dice co-efficient: 0.9574926162448677  Balanced Accuracy: 0.9866169300064997
# ImageID: 530. Dice co-efficient: 0.919948888652482  Balanced Accuracy: 0.9425702886743212
# ImageID: 531. Dice co-efficient: 0.9449765843304871  Balanced Accuracy: 0.9824586564739799
# ImageID: 551. Dice co-efficient: 0.7967561660822442  Balanced Accuracy: 0.8557686693588592
# ImageID: 552. Dice co-efficient: 0.9418633706933854  Balanced Accuracy: 0.984996538432199
# ImageID: 558. Dice co-efficient: 0.9617418685599003  Balanced Accuracy: 0.9851219449917873
# ImageID: 559. Dice co-efficient: 0.975388857341751  Balanced Accuracy: 0.9874655924220312
# ImageID: 560. Dice co-efficient: 0.9480251452971178  Balanced Accuracy: 0.9717935372189888
# ImageID: 562. Dice co-efficient: 0.9332632278102291  Balanced Accuracy: 0.9546871787975646
# ImageID: 567. Dice co-efficient: 0.9129037905411539  Balanced Accuracy: 0.9444056993745786
# ImageID: 587. Dice co-efficient: 0.9644770142396861  Balanced Accuracy: 0.9802832602308454
# ImageID: 595. Dice co-efficient: 0.9655523391291148  Balanced Accuracy: 0.9891422658369406
# ImageID: 617. Dice co-efficient: 0.9729480708400048  Balanced Accuracy: 0.9921077246117311
# ImageID: 619. Dice co-efficient: 0.9467811531015464  Balanced Accuracy: 0.9874714425167578
# ImageID: 623. Dice co-efficient: 0.9605662023832392  Balanced Accuracy: 0.9913601937756004
# ImageID: 627. Dice co-efficient: 0.9478413262364458  Balanced Accuracy: 0.9714858339847575
# ImageID: 628. Dice co-efficient: 0.9208188978951496  Balanced Accuracy: 0.9565095922611191
# ImageID: 634. Dice co-efficient: 0.9688175873591415  Balanced Accuracy: 0.9816474841758314
# ImageID: 700. Dice co-efficient: 0.9671945790551822  Balanced Accuracy: 0.9822450261558346
# ImageID: 702. Dice co-efficient: 0.9651787107350669  Balanced Accuracy: 0.9759757098215776
# ImageID: 725. Dice co-efficient: 0.9462600200567799  Balanced Accuracy: 0.9617006812505903
# ImageID: 735. Dice co-efficient: 0.9638726155048462  Balanced Accuracy: 0.9936040497164422
# ImageID: 737. Dice co-efficient: 0.8577440246761664  Balanced Accuracy: 0.9738637991143861
# ImageID: 739. Dice co-efficient: 0.9296704716244567  Balanced Accuracy: 0.9589692851017051
# ImageID: 741. Dice co-efficient: 0.877755433618956  Balanced Accuracy: 0.9763060823985548
# ImageID: 754. Dice co-efficient: 0.9407497831549918  Balanced Accuracy: 0.9694739277023168
# ImageID: 766. Dice co-efficient: 0.9511485689081742  Balanced Accuracy: 0.9775401770862923
# ImageID: 792. Dice co-efficient: 0.9349856379998771  Balanced Accuracy: 0.971912629599567
# ImageID: 805. Dice co-efficient: 0.9719740736392679  Balanced Accuracy: 0.9866642478065977
# ImageID: 810. Dice co-efficient: 0.4725207111634702  Balanced Accuracy: 0.9768766338852235
# ImageID: 813. Dice co-efficient: 0.5604653855144408  Balanced Accuracy: 0.8881034005182438
# ImageID: 833. Dice co-efficient: 0.08550305978942567  Balanced Accuracy: 0.9608661915749495
# ImageID: 834. Dice co-efficient: 0.9557344773945439  Balanced Accuracy: 0.9755267560894849
# ImageID: 843. Dice co-efficient: 0.8613772966863531  Balanced Accuracy: 0.9027626237265683
# ImageID: 856. Dice co-efficient: 0.9598570345216615  Balanced Accuracy: 0.9770273485276034
# ImageID: 863. Dice co-efficient: 0.9619767188513888  Balanced Accuracy: 0.9926557737303426
# ImageID: 874. Dice co-efficient: 0.9506677550804576  Balanced Accuracy: 0.967677775803325
# ImageID: 882. Dice co-efficient: 0.9694727630064373  Balanced Accuracy: 0.9915602923048495
# ImageID: 884. Dice co-efficient: 0.9772785089030156  Balanced Accuracy: 0.9904426918148632
# ImageID: 887. Dice co-efficient: 0.9543829200613867  Balanced Accuracy: 0.9814323708851355
# ImageID: 892. Dice co-efficient: 0.8880713175330653  Balanced Accuracy: 0.9457824263245116
# ImageID: 893. Dice co-efficient: 0.9535087407491665  Balanced Accuracy: 0.9841859592798345
# ImageID: 898. Dice co-efficient: 0.9447993065832543  Balanced Accuracy: 0.969565786024555
# ImageID: 952. Dice co-efficient: 0.9495850672119233  Balanced Accuracy: 0.9677774423788634
# ImageID: 956. Dice co-efficient: 0.9574870708101948  Balanced Accuracy: 0.9680333558436149
# ImageID: 958. Dice co-efficient: 0.9690375381066887  Balanced Accuracy: 0.9893076694251196
#
# -----------------------Final Segmentation metrics are as follows:---------------------------
# DSC = 93.2208 (+/-9.1389)
# Sensitivity = 95.3016 (+/-4.1031)
# Specificity = 98.9755 (+/-2.8824)
# Accuracy = 98.70497138 (+/-2.1632)
# IoU = 88.2174 (+/-10.9137)
# Balanced Accuracy = 97.1385 (+/-2.3031)

# %% [markdown]
# ## Evaluation of Mid-line regression sub-network

# %%
CurrentDirectory=os.getcwd()
Predictionpath = CurrentDirectory+'/Mask_V1/'
Prediction = glob.glob(Predictionpath+"*.png")
Prediction.sort()
# print(len(Prediction))

OriginalMidlineGT = glob.glob(CurrentDirectory+'/Test_midLine_GT/'+"*.png")
OriginalMidlineGT.sort()
# print(len(OriginalMidlineGT))

OriginalImage = glob.glob(CurrentDirectory+'/TestImage/'+"*.png")
OriginalImage.sort()
# print(len(OriginalImage))

midlinesavePath = CurrentDirectory+'/midline/'

i=0


AD_midline=[]

for Pred in Prediction:
    
    filename, file_extension = os.path.splitext(Pred) 
    
    if filename[-7:]=='midline':
        #------------------------------------Read the Prediction from SIMO--------------------------------
        imgPred = cv2.imread(Pred,0)
        tempimgPred = imgPred.copy()
        
        #-----------------------------------Read Original Image with Midline GT---------------------------
        orimg = cv2.imread(OriginalImage[i],-1)
        orimg = cv2.resize(orimg,(256,192))
        
        trueLine = cv2.imread(OriginalMidlineGT[i],0)
        trueLine = cv2.resize(trueLine,(256,192))
        i=i+1

        #-------------------------------Truncate the intensity lower than Threshold----------------------
        Threshold = (imgPred.max())-100
        imgPred[imgPred<Threshold]=0
        
        temp = cv2.merge((tempimgPred, tempimgPred, tempimgPred))
        temp [:,:,0]=0
        temp [:,:,2]=0 

        
        savelinePath=midlinesavePath+'ImgID_'+filename[-11:]+'_Prediction_.png'
        cv2.imwrite(savelinePath,cv2.addWeighted(temp,0.99,orimg,0.8,0))
                
        
        #-----------------------------Classic straight-line Hough transform----------------------------
        h, theta, d = hough_line(imgPred)        
        for _, angle, dist in zip(*hough_line_peaks(h, theta, d, min_distance=9, min_angle=10, threshold=0.5*h.max(), num_peaks=1)):
            y0 = (dist - 0 * np.cos(angle)) / np.sin(angle)
            y1 = (dist - imgPred.shape[1] * np.cos(angle)) / np.sin(angle)
        x0P = 0
        y0P = int(y0)
        x1P = imgPred.shape[1]
        y1P = int(y1)
        
        #-----------------------------Approximate Line-------------------------------------------------
        ApproximateLine=np.zeros_like(imgPred, dtype=np.uint8)
    
        cv2.line(ApproximateLine,(x0P,y0P),(x1P,y1P), 255, 1)
        
#         savelinePath=midlinesavePath+filename[-11:]+'_Approx_.png'
#         cv2.imwrite(savelinePath,ApproximateLine)  
        
        #---------------------------True Line approximation----------------------------------------------
        h, theta, d = hough_line(trueLine)        
        for _, angle, dist in zip(*hough_line_peaks(h, theta, d,min_distance=9, min_angle=10, threshold=0.5*h.max(), num_peaks=1)):
            y0 = (dist - 0 * np.cos(angle)) / np.sin(angle)
            y1 = (dist - imgPred.shape[1] * np.cos(angle)) / np.sin(angle)
        x0G = 0
        y0G = int(y0)
        x1G= imgPred.shape[1]
        y1G= int(y1)
        
        trueLine=np.zeros_like(trueLine, dtype=np.uint8)
    
        cv2.line(trueLine,(x0G,y0G),(x1G,y1G), 255, 1)   
        
        
        #-----------------------Overlay with original Image------------------------------------------       
        temp = cv2.merge((ApproximateLine, ApproximateLine, ApproximateLine))
        temp [:,:,0]=0
        temp [:,:,2]=0 
        
        temp2 = cv2.merge((trueLine, trueLine, trueLine))
        temp2 [:,:,0]=0 

        
        dummy = cv2.addWeighted(temp,0.99,orimg,0.8,0)
        
        dummy = cv2.addWeighted(temp2,0.99,dummy,0.8,0)
        
        
        #----------------------mean Angular Displacement Error Measurements--------------------------

        AngularDisplacement=Angular_Displacement(height = 192,
                                                width = 256,
                                                L1x1 = x0P,
                                                L1y1 = y0P,
                                                L1x2 = x1P,
                                                L1y2 = y1P,
                                                L2x1 = x0G,
                                                L2y1 = y0G,
                                                L2x2 = x1G,
                                                L2y2 = y1G)
        
        print('ImageID: '+ filename[-11:-8]+'.  AD in radian: '+ str(AngularDisplacement)
              + '  AD in degrees: ' + str(degrees(AngularDisplacement)))
        
        
        #------------------------ApproximateLine with True Line---------------------------------------
        
        TruePlusApproximation = ApproximateLine+trueLine
        
        font                   = cv2.FONT_HERSHEY_SIMPLEX
        bottomLeftCornerOfText = (80,185)
        fontScale              = 1
        fontColor              = (255,255,255)
        lineType               = 2

        cv2.putText(dummy,str(round (degrees(AngularDisplacement),2)), 
            bottomLeftCornerOfText, 
            font, 
            fontScale,
            fontColor,
            lineType)

#         savelinePath=midlinesavePath+filename[-11:]+'_ApproxPlusTrue_.png'
#         cv2.imwrite(savelinePath,TruePlusApproximation) 
        
        savelinePath=midlinesavePath+'ImgID_'+filename[-11:]+'_Overlay_with_Approx_true_.png'
        cv2.imwrite(savelinePath,dummy)  

        AD_midline.append(AngularDisplacement)
  
print()
print('-----------------------Final mean Angular Displacement (mAD)---------------------------')
print()
print('mAD in radians: '+ str(np.mean(AD_midline)) + '  mAD in degrees: ' + str(degrees(np.mean(AD_midline))))
print('std. AD in radians: '+ str(math.sqrt(np.mean((np.array(AD_midline)-np.mean(AD_midline))**2))) 
      + '  median AD in radians: ' + str(np.median(AD_midline)))
# Out:
# ImageID: 011.  AD in radian: 0.0169724338182852  AD in degrees: 0.9724488258528486
# ImageID: 015.  AD in radian: 0.0187424965076547  AD in degrees: 1.073865947427297
# ImageID: 017.  AD in radian: 0.0189826206770451  AD in degrees: 1.0876240488924558
# ImageID: 020.  AD in radian: 0.0539304676598411  AD in degrees: 3.0899881840756698
# ImageID: 037.  AD in radian: 0.0179297698816286  AD in degrees: 1.027300141858095
# ImageID: 046.  AD in radian: 0.0202261334223558  AD in degrees: 1.1588720809694828
# ImageID: 062.  AD in radian: 0.0184651217699458  AD in degrees: 1.0579735456130295
# ImageID: 070.  AD in radian: 0.0179297698816282  AD in degrees: 1.027300141858076
# ImageID: 075.  AD in radian: 0.0351043121979448  AD in degrees: 2.0113289316518532
# ImageID: 079.  AD in radian: 0.0506682040304566  AD in degrees: 2.903074246452908
# ImageID: 083.  AD in radian: 0.0181301593709421  AD in degrees: 1.0387816138545416
# ImageID: 084.  AD in radian: 0.0176648224527610  AD in degrees: 1.0121197723911426
# ImageID: 085.  AD in radian: 0.0171417246426608  AD in degrees: 0.9821484755998626
# ImageID: 091.  AD in radian: 0.0333518543612353  AD in degrees: 1.9109204938337712
# ImageID: 108.  AD in radian: 0.0142881469020881  AD in degrees: 0.8186505145525672
# ImageID: 110.  AD in radian: 0.0147624799865570  AD in degrees: 0.8458277983760615
# ImageID: 114.  AD in radian: 0.0216249709303413  AD in degrees: 1.2390195664016508
# ImageID: 125.  AD in radian: 0.0344195323625059  AD in degrees: 1.9720939371855422
# ImageID: 128.  AD in radian: 0.0193200196687576  AD in degrees: 1.1069555871295516
# ImageID: 135.  AD in radian: 0.0701969710718704  AD in degrees: 4.021990177020107
# ImageID: 155.  AD in radian: 0.00626871999382646  AD in degrees: 0.3591711985955317
# ImageID: 160.  AD in radian: 0  AD in degrees: 0.0
# ImageID: 161.  AD in radian: 0  AD in degrees: 0.0
# ImageID: 162.  AD in radian: 0.0210973610963204  AD in degrees: 1.208789749682653
# ImageID: 169.  AD in radian: 0.0355580306572588  AD in degrees: 2.037325084457721
# ImageID: 171.  AD in radian: 0  AD in degrees: 0.0
# ImageID: 173.  AD in radian: 0.0179297698816278  AD in degrees: 1.0273001418580496
# ImageID: 187.  AD in radian: 0.0150565046731558  AD in degrees: 0.8626741719908283
# ImageID: 188.  AD in radian: 0.0192875732444802  AD in degrees: 1.1050965439581648
# ImageID: 197.  AD in radian: 0  AD in degrees: 0.0
# ImageID: 198.  AD in radian: 0.0169076287945126  AD in degrees: 0.9687357714994341
# ImageID: 199.  AD in radian: 0  AD in degrees: 0.0
# ImageID: 210.  AD in radian: 0.0456799746762983  AD in degrees: 2.6172697572163695
# ImageID: 213.  AD in radian: 0.0132881040758413  AD in degrees: 0.7613522812762925
# ImageID: 214.  AD in radian: 0.0172572072480195  AD in degrees: 0.9887651414940897
# ImageID: 215.  AD in radian: 0.0379960055885062  AD in degrees: 2.177010758576895
# ImageID: 223.  AD in radian: 0.0364137695223167  AD in degrees: 2.086355309790854
# ImageID: 233.  AD in radian: 0  AD in degrees: 0.0
# ImageID: 236.  AD in radian: 0.0193216685272488  AD in degrees: 1.1070500597621118
# ImageID: 238.  AD in radian: 0.0543435394039425  AD in degrees: 3.113655451648792
# ImageID: 239.  AD in radian: 0.0525816228841558  AD in degrees: 3.012705071210637
# ImageID: 241.  AD in radian: 0.0363213786785105  AD in degrees: 2.0810617043751085
# ImageID: 245.  AD in radian: 0.123066814031931  AD in degrees: 7.051209042151015
# ImageID: 250.  AD in radian: 0.0308756967259394  AD in degrees: 1.769047111922224
# ImageID: 253.  AD in radian: 0.0702183003425600  AD in degrees: 4.02321225421071
# ImageID: 254.  AD in radian: 0.106512090543996  AD in degrees: 6.102693255286273
# ImageID: 260.  AD in radian: 0.0127003789060575  AD in degrees: 0.727678109534072
# ImageID: 261.  AD in radian: 0.0184321539136664  AD in degrees: 1.056084626588628
# ImageID: 264.  AD in radian: 0.0333478184735975  AD in degrees: 1.9106892545055336
# ImageID: 266.  AD in radian: 0.0264480232779893  AD in degrees: 1.515360110292545
# ImageID: 271.  AD in radian: 0.00618914525383753  AD in degrees: 0.35461190183831526
# ImageID: 272.  AD in radian: 0.0294450894953942  AD in degrees: 1.6870793554710801
# ImageID: 273.  AD in radian: 0.0190320748272277  AD in degrees: 1.0904575629773219
# ImageID: 275.  AD in radian: 0.00626994301410418  AD in degrees: 0.3592412724957042
# ImageID: 281.  AD in radian: 0.0143592531012524  AD in degrees: 0.8227245996619031
# ImageID: 291.  AD in radian: 0.0333518543612341  AD in degrees: 1.9109204938337012
# ImageID: 301.  AD in radian: 0.0696826519981563  AD in degrees: 3.99252186477321
# ImageID: 302.  AD in radian: 0.00627534265613709  AD in degrees: 0.35955064919507124
# ImageID: 309.  AD in radian: 0.00675810687692602  AD in degrees: 0.3872110015461984
# ImageID: 310.  AD in radian: 0.0181009834266907  AD in degrees: 1.0371099553856302
# ImageID: 315.  AD in radian: 0.0190117508297888  AD in degrees: 1.08929308370124
# ImageID: 316.  AD in radian: 0.0150271100313040  AD in degrees: 0.8609899830724199
# ImageID: 319.  AD in radian: 0.0282022397995457  AD in degrees: 1.6158693133298456
# ImageID: 321.  AD in radian: 0.0177515294211357  AD in degrees: 1.0170877157333829
# ImageID: 324.  AD in radian: 0.0582042900444058  AD in degrees: 3.3348601690997675
# ImageID: 328.  AD in radian: 0.124609040457742  AD in degrees: 7.139572107403515
# ImageID: 329.  AD in radian: 0.0683892620936386  AD in degrees: 3.9184160819795153
# ImageID: 331.  AD in radian: 0.0317738741733236  AD in degrees: 1.8205088889111698
# ImageID: 339.  AD in radian: 0.0525099404215495  AD in degrees: 3.0085979686381887
# ImageID: 343.  AD in radian: 0.0238541776456220  AD in degrees: 1.3667437028494565
# ImageID: 345.  AD in radian: 0.0353982856528027  AD in degrees: 2.0281723699040897
# ImageID: 347.  AD in radian: 0.0126267454377073  AD in degrees: 0.7234592225666973
# ImageID: 351.  AD in radian: 0.0391425011695317  AD in degrees: 2.2427001166000546
# ImageID: 360.  AD in radian: 0  AD in degrees: 0.0
# ImageID: 362.  AD in radian: 0.133472998566367  AD in degrees: 7.647439496808527
# ImageID: 368.  AD in radian: 0.00760749427130733  AD in degrees: 0.4358773144158619
# ImageID: 372.  AD in radian: 0.00561701548829601  AD in degrees: 0.3218312809389765
# ImageID: 373.  AD in radian: 0.0519579675617119  AD in degrees: 2.9769722533637313
# ImageID: 376.  AD in radian: 0  AD in degrees: 0.0
# ImageID: 379.  AD in radian: 0  AD in degrees: 0.0
# ImageID: 393.  AD in radian: 0.00628444029538761  AD in degrees: 0.36007190552765833
# ImageID: 399.  AD in radian: 0.0883732441413571  AD in degrees: 5.0634139111789915
# ImageID: 400.  AD in radian: 0  AD in degrees: 0.0
# ImageID: 406.  AD in radian: 0.0338341672324480  AD in degrees: 1.9385549857590947
# ImageID: 408.  AD in radian: 0.0192018645979413  AD in degrees: 1.1001858002437064
# ImageID: 409.  AD in radian: 0.0177335506783399  AD in degrees: 1.0160576096502316
# ImageID: 410.  AD in radian: 0.0189826206770441  AD in degrees: 1.0876240488923965
# ImageID: 412.  AD in radian: 0.0162065836477326  AD in degrees: 0.9285688433408152
# ImageID: 418.  AD in radian: 0.0190415388123639  AD in degrees: 1.0909998093830036
# ImageID: 426.  AD in radian: 0.0184321539136697  AD in degrees: 1.0560846265888146
# ImageID: 430.  AD in radian: 0.0173958013889447  AD in degrees: 0.9967060008343442
# ImageID: 431.  AD in radian: 0.0877619713896079  AD in degrees: 5.0283905623724126
# ImageID: 435.  AD in radian: 0.0530695029273478  AD in degrees: 3.0406585385941964
# ImageID: 436.  AD in radian: 0.0362197067157722  AD in degrees: 2.07523633001539
# ImageID: 438.  AD in radian: 0.0169597386140635  AD in degrees: 0.9717214442308922
# ImageID: 440.  AD in radian: 0.0171912629828517  AD in degrees: 0.9849868134168822
# ImageID: 442.  AD in radian: 0.0172855782721364  AD in degrees: 0.9903906814364545
# ImageID: 454.  AD in radian: 0.0703880152688316  AD in degrees: 4.032936203206447
# ImageID: 456.  AD in radian: 0.0231919003262028  AD in degrees: 1.3287980075794985
# ImageID: 471.  AD in radian: 0.0168978423199131  AD in degrees: 0.9681750478085712
# ImageID: 474.  AD in radian: 0  AD in degrees: 0.0
# ImageID: 483.  AD in radian: 0.0549684394067909  AD in degrees: 3.1494595844297146
# ImageID: 490.  AD in radian: 0  AD in degrees: 0.0
# ImageID: 495.  AD in radian: 0.0351242120120444  AD in degrees: 2.0124691070128518
# ImageID: 500.  AD in radian: 0.193536951733425  AD in degrees: 11.088850514152384
# ImageID: 502.  AD in radian: 0.0527121216032790  AD in degrees: 3.0201820970482585
# ImageID: 504.  AD in radian: 0.0175953106877669  AD in degrees: 1.008137041630472
# ImageID: 507.  AD in radian: 0.0878251937417086  AD in degrees: 5.032012936318674
# ImageID: 512.  AD in radian: 0.0774178818744060  AD in degrees: 4.435717890245818
# ImageID: 530.  AD in radian: 0.0351485157255794  AD in degrees: 2.013861607224903
# ImageID: 531.  AD in radian: 0.0528735604390396  AD in degrees: 3.029431860986844
# ImageID: 551.  AD in radian: 0.353258027475910  AD in degrees: 20.240194053486125
# ImageID: 552.  AD in radian: 0.0315522536222965  AD in degrees: 1.8078109666839515
# ImageID: 558.  AD in radian: 0.0268605789526515  AD in degrees: 1.5389978092648608
# ImageID: 559.  AD in radian: 0.0527337365292473  AD in degrees: 3.02142054108073
# ImageID: 560.  AD in radian: 0.0492504914566736  AD in degrees: 2.821845299412517
# ImageID: 562.  AD in radian: 0.0687848659708915  AD in degrees: 3.9410825145051214
# ImageID: 567.  AD in radian: 0.0113968648547462  AD in degrees: 0.6529922558579355
# ImageID: 587.  AD in radian: 0.0179297698816286  AD in degrees: 1.027300141858095
# ImageID: 595.  AD in radian: 0.0361379133818990  AD in degrees: 2.070549917192154
# ImageID: 617.  AD in radian: 0.0533580825939221  AD in degrees: 3.057192935542195
# ImageID: 619.  AD in radian: 0.0331762227215309  AD in degrees: 1.9008575421297478
# ImageID: 623.  AD in radian: 0.0896405777791905  AD in degrees: 5.136026779861806
# ImageID: 627.  AD in radian: 0.0529131576742839  AD in degrees: 3.0317006154467316
# ImageID: 628.  AD in radian: 0.0523026553108947  AD in degrees: 2.9967214066417647
# ImageID: 634.  AD in radian: 0.0528735604390389  AD in degrees: 3.0294318609868074
# ImageID: 700.  AD in radian: 0.0179676213543710  AD in degrees: 1.0294688714945932
# ImageID: 702.  AD in radian: 0.0161325117813728  AD in degrees: 0.9243248380177378
# ImageID: 725.  AD in radian: 0.0226804900001921  AD in degrees: 1.2994963542996734
# ImageID: 735.  AD in radian: 0.0193529796777813  AD in degrees: 1.1088440565393218
# ImageID: 737.  AD in radian: 0.153921595698068  AD in degrees: 8.819057809418288
# ImageID: 739.  AD in radian: 0.0878193278162114  AD in degrees: 5.031676843544746
# ImageID: 741.  AD in radian: 0.229056190963506  AD in degrees: 13.123953013551501
# ImageID: 754.  AD in radian: 0.0355580306572585  AD in degrees: 2.037325084457706
# ImageID: 766.  AD in radian: 0.0540259788632134  AD in degrees: 3.0954605729251234
# ImageID: 792.  AD in radian: 0.0532527547800988  AD in degrees: 3.051158096344784
# ImageID: 805.  AD in radian: 0.00707902931858027  AD in degrees: 0.40559850300402056
# ImageID: 810.  AD in radian: 0.0676708926999385  AD in degrees: 3.8772565475891305
# ImageID: 813.  AD in radian: 0.137721928209089  AD in degrees: 7.890885232784511
# ImageID: 833.  AD in radian: 0.0537273348993024  AD in degrees: 3.078349534215961
# ImageID: 834.  AD in radian: 0.0379087778248338  AD in degrees: 2.1720129758621045
# ImageID: 843.  AD in radian: 0.0369298553707144  AD in degrees: 2.1159248507704693
# ImageID: 856.  AD in radian: 0.0176152810486863  AD in degrees: 1.0092812590265061
# ImageID: 863.  AD in radian: 0.0147624799865550  AD in degrees: 0.8458277983759438
# ImageID: 874.  AD in radian: 0.00751897139915142  AD in degrees: 0.43080532745095196
# ImageID: 882.  AD in radian: 0.0519579675617147  AD in degrees: 2.9769722533638903
# ImageID: 884.  AD in radian: 0.0162516528062019  AD in degrees: 0.9311511159073116
# ImageID: 887.  AD in radian: 0.0175544015089682  AD in degrees: 1.0057931183419597
# ImageID: 892.  AD in radian: 0.0881164473039504  AD in degrees: 5.048700536203277
# ImageID: 893.  AD in radian: 0.0364137695223164  AD in degrees: 2.0863553097908354
# ImageID: 898.  AD in radian: 0.0504471941769716  AD in degrees: 2.8904113146174177
# ImageID: 952.  AD in radian: 0.0927996267563627  AD in degrees: 5.317026953528891
# ImageID: 956.  AD in radian: 0.0501056968042938  AD in degrees: 2.870844956448171
# ImageID: 958.  AD in radian: 0.0195180481823221  AD in degrees: 1.1183017851800443
#
# -----------------------Final mean Angular Displacement (mAD)---------------------------
#
# mAD in radians: 0.0390199485836223  mAD in degrees: 2.2356783706590306
# std. AD in radians: 0.04376686796590761  median AD in radians: 0.0235230389859124

# %% [markdown]
# ## Evaluation of Tip-point regression sub-network

# %%
PredictionPath = CurrentDirectory+'/Mask_V1/'
Prediction = glob.glob(PredictionPath+"*.png")
Prediction.sort()
# print(len(Prediction))

OriginaltipGT = glob.glob(CurrentDirectory+'/Test_tip_GT/'+"*.png")
OriginaltipGT.sort()
# print(len(OriginaltipGT))

OriginalImage = glob.glob(CurrentDirectory+'/TestImage/'+"*.png")
OriginalImage.sort()
# print(len(OriginalImage))

tipsavePath = CurrentDirectory+'/TIP/'

i=0

Euclidean_Tip=[]

for Pred in Prediction:
    
    filename, file_extension = os.path.splitext(Pred) 
    
    if filename[-3:]=='tip':
        #--------------------------Read the Prediction from SIMO----------------------------------
        imgPred = cv2.imread(Pred,0)
        temp = imgPred.copy()
        
        #-------------------------Read Original Image with TIP GT---------------------------------
        orimg = cv2.imread(OriginalImage[i],-1)
        orimg = cv2.resize(orimg,(256,192))
        
        truepoint = cv2.imread(OriginaltipGT[i],0)
        truepoint = cv2.resize(truepoint,(256,192))
        i=i+1

        #----------------------Truncate the intensity lower than Threshold-----------------------
        Threshold = (imgPred.max())-100
        imgPred[imgPred<Threshold]=0
               
#         savelinePath=tipsavePath+filename[-7:]+'_Pred_.png'
#         cv2.imwrite(savelinePath,imgPred)
        
        #-----------------------Overlay with original Image--------------------------------------       
        temp = cv2.merge((imgPred, imgPred, imgPred))
        temp [:,:,0]=0
        temp [:,:,2]=0   
        
        temp2 = cv2.merge((truepoint, truepoint, truepoint))
        temp2 [:,:,0]=0

        dummy = cv2.addWeighted(temp, 0.8, orimg, 0.8, 0)
        dummy = cv2.addWeighted(temp2, 0.8, dummy, 0.8, 0)
        
                
        #------------------------Euclidean Distance-----------------------------------------------
        XY_PredictedPoint = np.argwhere(imgPred.max() == imgPred)
        XY_truePoint = np.argwhere(truepoint.max() == truepoint)
        
        X_P = XY_PredictedPoint[0][1]
        Y_P = XY_PredictedPoint[0][0]
        
        X_G = XY_truePoint[0][1]
        Y_G = XY_truePoint[0][0]  

        euclidean_distance = distance.euclidean((X_P, Y_P), (X_G, Y_G))
        print('ImageID: '+ filename[-7:-4]+ '.   Euclidean Distance in pixels: '+ str(euclidean_distance))
        Euclidean_Tip.append(euclidean_distance)
        
        #--------------------Approximate point with True point---------------------------------------
        
        font                   = cv2.FONT_HERSHEY_SIMPLEX
        bottomLeftCornerOfText = (80,185)
        fontScale              = 1
        fontColor              = (255,255,255)
        lineType               = 2

        cv2.putText(dummy,str(round(euclidean_distance,2)), 
            bottomLeftCornerOfText, 
            font, 
            fontScale,
            fontColor,
            lineType)

        savelinePath=tipsavePath+'ImgID_'+filename[-7:]+'_Overlay_Pred_True.png'
        cv2.imwrite(savelinePath,dummy)  

        
print()
print('-----------------------Final Mean Euclidean Distance (mED)---------------------------')
print()
print('Mean Euclidean Distance (mED) in pixels: '+ str(np.mean(Euclidean_Tip)))
print('std. Euclidean Distance (ED): '+ str(math.sqrt(np.mean((np.array(Euclidean_Tip)-np.mean(Euclidean_Tip))**2))) 
      + '  median Euclidean Distance (ED): ' + str(np.median(Euclidean_Tip)))
# Out:
# ImageID: 011.   Euclidean Distance in pixels: 2.23606797749979
# ImageID: 015.   Euclidean Distance in pixels: 2.8284271247461903
# ImageID: 017.   Euclidean Distance in pixels: 6.082762530298219
# ImageID: 020.   Euclidean Distance in pixels: 3.1622776601683795
# ImageID: 037.   Euclidean Distance in pixels: 1.0
# ImageID: 046.   Euclidean Distance in pixels: 1.4142135623730951
# ImageID: 062.   Euclidean Distance in pixels: 0.0
# ImageID: 070.   Euclidean Distance in pixels: 7.280109889280518
# ImageID: 075.   Euclidean Distance in pixels: 1.0
# ImageID: 079.   Euclidean Distance in pixels: 2.23606797749979
# ImageID: 083.   Euclidean Distance in pixels: 5.0990195135927845
# ImageID: 084.   Euclidean Distance in pixels: 5.385164807134504
# ImageID: 085.   Euclidean Distance in pixels: 28.0178514522438
# ImageID: 091.   Euclidean Distance in pixels: 4.0
# ImageID: 108.   Euclidean Distance in pixels: 1.4142135623730951
# ImageID: 110.   Euclidean Distance in pixels: 1.4142135623730951
# ImageID: 114.   Euclidean Distance in pixels: 22.47220505424423
# ImageID: 125.   Euclidean Distance in pixels: 2.8284271247461903
# ImageID: 128.   Euclidean Distance in pixels: 2.23606797749979
# ImageID: 135.   Euclidean Distance in pixels: 1.0
# ImageID: 155.   Euclidean Distance in pixels: 5.0
# ImageID: 160.   Euclidean Distance in pixels: 5.0990195135927845
# ImageID: 161.   Euclidean Distance in pixels: 6.4031242374328485
# ImageID: 162.   Euclidean Distance in pixels: 6.0
# ImageID: 169.   Euclidean Distance in pixels: 5.385164807134504
# ImageID: 171.   Euclidean Distance in pixels: 4.123105625617661
# ImageID: 173.   Euclidean Distance in pixels: 5.385164807134504
# ImageID: 187.   Euclidean Distance in pixels: 3.1622776601683795
# ImageID: 188.   Euclidean Distance in pixels: 63.50590523722971
# ImageID: 197.   Euclidean Distance in pixels: 2.23606797749979
# ImageID: 198.   Euclidean Distance in pixels: 1.4142135623730951
# ImageID: 199.   Euclidean Distance in pixels: 2.8284271247461903
# ImageID: 210.   Euclidean Distance in pixels: 1.0
# ImageID: 213.   Euclidean Distance in pixels: 8.602325267042627
# ImageID: 214.   Euclidean Distance in pixels: 2.0
# ImageID: 215.   Euclidean Distance in pixels: 0.0
# ImageID: 223.   Euclidean Distance in pixels: 1.0
# ImageID: 233.   Euclidean Distance in pixels: 1.0
# ImageID: 236.   Euclidean Distance in pixels: 3.605551275463989
# ImageID: 238.   Euclidean Distance in pixels: 1.0
# ImageID: 239.   Euclidean Distance in pixels: 0.0
# ImageID: 241.   Euclidean Distance in pixels: 1.0
# ImageID: 245.   Euclidean Distance in pixels: 3.1622776601683795
# ImageID: 250.   Euclidean Distance in pixels: 4.242640687119285
# ImageID: 253.   Euclidean Distance in pixels: 5.656854249492381
# ImageID: 254.   Euclidean Distance in pixels: 0.0
# ImageID: 260.   Euclidean Distance in pixels: 0.0
# ImageID: 261.   Euclidean Distance in pixels: 1.4142135623730951
# ImageID: 264.   Euclidean Distance in pixels: 3.0
# ImageID: 266.   Euclidean Distance in pixels: 5.0
# ImageID: 271.   Euclidean Distance in pixels: 2.0
# ImageID: 272.   Euclidean Distance in pixels: 2.8284271247461903
# ImageID: 273.   Euclidean Distance in pixels: 1.4142135623730951
# ImageID: 275.   Euclidean Distance in pixels: 2.0
# ImageID: 281.   Euclidean Distance in pixels: 4.47213595499958
# ImageID: 291.   Euclidean Distance in pixels: 1.0
# ImageID: 301.   Euclidean Distance in pixels: 76.05918747922567
# ImageID: 302.   Euclidean Distance in pixels: 2.23606797749979
# ImageID: 309.   Euclidean Distance in pixels: 1.0
# ImageID: 310.   Euclidean Distance in pixels: 1.4142135623730951
# ImageID: 315.   Euclidean Distance in pixels: 3.1622776601683795
# ImageID: 316.   Euclidean Distance in pixels: 3.1622776601683795
# ImageID: 319.   Euclidean Distance in pixels: 4.123105625617661
# ImageID: 321.   Euclidean Distance in pixels: 1.0
# ImageID: 324.   Euclidean Distance in pixels: 2.0
# ImageID: 328.   Euclidean Distance in pixels: 2.0
# ImageID: 329.   Euclidean Distance in pixels: 4.123105625617661
# ImageID: 331.   Euclidean Distance in pixels: 3.605551275463989
# ImageID: 339.   Euclidean Distance in pixels: 31.78049716414141
# ImageID: 343.   Euclidean Distance in pixels: 2.0
# ImageID: 345.   Euclidean Distance in pixels: 4.123105625617661
# ImageID: 347.   Euclidean Distance in pixels: 1.0
# ImageID: 351.   Euclidean Distance in pixels: 3.605551275463989
# ImageID: 360.   Euclidean Distance in pixels: 1.0
# ImageID: 362.   Euclidean Distance in pixels: 3.1622776601683795
# ImageID: 368.   Euclidean Distance in pixels: 3.605551275463989
# ImageID: 372.   Euclidean Distance in pixels: 2.23606797749979
# ImageID: 373.   Euclidean Distance in pixels: 7.0710678118654755
# ImageID: 376.   Euclidean Distance in pixels: 4.123105625617661
# ImageID: 379.   Euclidean Distance in pixels: 5.0990195135927845
# ImageID: 393.   Euclidean Distance in pixels: 13.038404810405298
# ImageID: 399.   Euclidean Distance in pixels: 2.0
# ImageID: 400.   Euclidean Distance in pixels: 2.23606797749979
# ImageID: 406.   Euclidean Distance in pixels: 0.0
# ImageID: 408.   Euclidean Distance in pixels: 7.0710678118654755
# ImageID: 409.   Euclidean Distance in pixels: 4.123105625617661
# ImageID: 410.   Euclidean Distance in pixels: 42.15447781671598
# ImageID: 412.   Euclidean Distance in pixels: 1.0
# ImageID: 418.   Euclidean Distance in pixels: 2.0
# ImageID: 426.   Euclidean Distance in pixels: 2.0
# ImageID: 430.   Euclidean Distance in pixels: 4.0
# ImageID: 431.   Euclidean Distance in pixels: 7.0
# ImageID: 435.   Euclidean Distance in pixels: 6.324555320336759
# ImageID: 436.   Euclidean Distance in pixels: 4.0
# ImageID: 438.   Euclidean Distance in pixels: 2.8284271247461903
# ImageID: 440.   Euclidean Distance in pixels: 3.0
# ImageID: 442.   Euclidean Distance in pixels: 3.0
# ImageID: 454.   Euclidean Distance in pixels: 10.198039027185569
# ImageID: 456.   Euclidean Distance in pixels: 6.324555320336759
# ImageID: 471.   Euclidean Distance in pixels: 2.0
# ImageID: 474.   Euclidean Distance in pixels: 2.0
# ImageID: 483.   Euclidean Distance in pixels: 5.385164807134504
# ImageID: 490.   Euclidean Distance in pixels: 2.0
# ImageID: 495.   Euclidean Distance in pixels: 3.0
# ImageID: 500.   Euclidean Distance in pixels: 5.830951894845301
# ImageID: 502.   Euclidean Distance in pixels: 4.123105625617661
# ImageID: 504.   Euclidean Distance in pixels: 2.23606797749979
# ImageID: 507.   Euclidean Distance in pixels: 2.23606797749979
# ImageID: 512.   Euclidean Distance in pixels: 1.4142135623730951
# ImageID: 530.   Euclidean Distance in pixels: 2.23606797749979
# ImageID: 531.   Euclidean Distance in pixels: 1.4142135623730951
# ImageID: 551.   Euclidean Distance in pixels: 78.63841300535
# ImageID: 552.   Euclidean Distance in pixels: 7.810249675906654
# ImageID: 558.   Euclidean Distance in pixels: 1.0
# ImageID: 559.   Euclidean Distance in pixels: 1.0
# ImageID: 560.   Euclidean Distance in pixels: 4.123105625617661
# ImageID: 562.   Euclidean Distance in pixels: 4.47213595499958
# ImageID: 567.   Euclidean Distance in pixels: 1.0
# ImageID: 587.   Euclidean Distance in pixels: 1.0
# ImageID: 595.   Euclidean Distance in pixels: 1.0
# ImageID: 617.   Euclidean Distance in pixels: 1.4142135623730951
# ImageID: 619.   Euclidean Distance in pixels: 1.4142135623730951
# ImageID: 623.   Euclidean Distance in pixels: 0.0
# ImageID: 627.   Euclidean Distance in pixels: 8.94427190999916
# ImageID: 628.   Euclidean Distance in pixels: 2.0
# ImageID: 634.   Euclidean Distance in pixels: 2.23606797749979
# ImageID: 700.   Euclidean Distance in pixels: 4.47213595499958
# ImageID: 702.   Euclidean Distance in pixels: 2.23606797749979
# ImageID: 725.   Euclidean Distance in pixels: 4.123105625617661
# ImageID: 735.   Euclidean Distance in pixels: 41.88078318274385
# ImageID: 737.   Euclidean Distance in pixels: 65.21502894272147
# ImageID: 739.   Euclidean Distance in pixels: 38.2099463490856
# ImageID: 741.   Euclidean Distance in pixels: 2.0
# ImageID: 754.   Euclidean Distance in pixels: 8.06225774829855
# ImageID: 766.   Euclidean Distance in pixels: 3.1622776601683795
# ImageID: 792.   Euclidean Distance in pixels: 3.1622776601683795
# ImageID: 805.   Euclidean Distance in pixels: 3.1622776601683795
# ImageID: 810.   Euclidean Distance in pixels: 70.21395872616783
# ImageID: 813.   Euclidean Distance in pixels: 77.07788269017254
# ImageID: 833.   Euclidean Distance in pixels: 31.064449134018133
# ImageID: 834.   Euclidean Distance in pixels: 5.0990195135927845
# ImageID: 843.   Euclidean Distance in pixels: 1.4142135623730951
# ImageID: 856.   Euclidean Distance in pixels: 19.79898987322333
# ImageID: 863.   Euclidean Distance in pixels: 11.313708498984761
# ImageID: 874.   Euclidean Distance in pixels: 39.6232255123179
# ImageID: 882.   Euclidean Distance in pixels: 25.632011235952593
# ImageID: 884.   Euclidean Distance in pixels: 98.41239759298622
# ImageID: 887.   Euclidean Distance in pixels: 96.87620966986684
# ImageID: 892.   Euclidean Distance in pixels: 6.4031242374328485
# ImageID: 893.   Euclidean Distance in pixels: 27.018512172212592
# ImageID: 898.   Euclidean Distance in pixels: 27.85677655436824
# ImageID: 952.   Euclidean Distance in pixels: 1.4142135623730951
# ImageID: 956.   Euclidean Distance in pixels: 2.8284271247461903
# ImageID: 958.   Euclidean Distance in pixels: 1.0
#
# -----------------------Final Mean Euclidean Distance (mED)---------------------------
#
# Mean Euclidean Distance (mED) in pixels: 9.290264508988828
# std. Euclidean Distance (ED): 18.270587346234908  median Euclidean Distance (ED): 3.1622776601683795

# %% [markdown]
# ## Evaluation of Edge-Line regression sub-network

# %%
testGene = CurrentDirectory+'/Mask_V1/'
Prediction = glob.glob(testGene+"*.png")
Prediction.sort()
# print(len(Prediction))

OriginalupGT = glob.glob(CurrentDirectory+'/Test_upLine_GT/'+"*.png")
OriginalupGT.sort()
# print(len(OriginalupGT))


OriginallowGT = glob.glob(CurrentDirectory+'/Test_lowerLine_GT/'+"*.png")
OriginallowGT.sort()
# print(len(OriginallowGT))


OriginalImage = glob.glob(CurrentDirectory+'/TestImage/'+"*.png")
OriginalImage.sort()
# print(len(OriginalImage))

midlinesavePath = CurrentDirectory+'/BothLine/'

i=0

AngularDisplacement_Line_1 = []
AngularDisplacement_Line_2 = []
bothError=[]

for Pred in Prediction:
    
    filename, file_extension = os.path.splitext(Pred) 
    
    if filename[-8:]=='bothline':
        #--------------------------Read the Prediction from SIMO----------------------------------------
        imgPred = cv2.imread(Pred,0)
        temp = imgPred.copy()
        temp2 = imgPred.copy()
        
        #-------------------------Read Original Image with Midline GT-----------------------------------
        orimg = cv2.imread(OriginalImage[i],-1)
        orimg = cv2.resize(orimg,(256,192))
        
        up = cv2.imread(OriginalupGT[i],0)
        up = cv2.resize(up,(256,192))
        
        up[up<100]=0
        up[up>100]=255
        
        low = cv2.imread(OriginallowGT[i],0)
        low = cv2.resize(low,(256,192))
        low[low<100]=0
        low[low>100]=255
        
        trueline=up+low
        
        i=i+1

        #-----------------------Truncate the intensity lower than Threshold--------------------------
        imgPredtemp=imgPred.copy()
        
        Threshold = (imgPred.max())-100
        imgPred[imgPred<Threshold]=0
        imgPredtemp[imgPredtemp<Threshold-30]=0
        
        
        
#         savelinePath=midlinesavePath+filename[-13:]+'_Pred_.png'
#         cv2.imwrite(savelinePath,imgPred)
        
#         savelinePath=midlinesavePath+filename[-13:]+'_true_.png'
#         cv2.imwrite(savelinePath,trueline)
        
#         savelinePath=midlinesavePath+filename[-13:]+'_truePLUSPred_.png'
#         cv2.imwrite(savelinePath,trueline+imgPred)
                
        
        #-----------------------Classic straight-line Hough transform-------------------------------
        h, theta, d = hough_line(imgPred)        
        for _, angle, dist in zip(*hough_line_peaks(h, theta, d,min_distance=9, min_angle=10, threshold=0.5*h.max(), num_peaks=1)):
            y0 = (dist - 0 * np.cos(angle)) / np.sin(angle)
            y1 = (dist - imgPred.shape[1] * np.cos(angle)) / np.sin(angle)
        x0P1 = 0
        y0P1 = int(y0)
        x1P1 = imgPred.shape[1]
        y1P1 = int(y1)
        
        #-------------------------Approximate Line_1------------------------------------------------
        ApproximateLine1=np.zeros_like(imgPred, dtype=np.uint8)
    
        cv2.line(ApproximateLine1,(x0P1,y0P1),(x1P1,y1P1), 255, 1)       
        
        #------------------------Classic straight-line Hough transform------------------------------
        temp=np.zeros_like(imgPred, dtype=np.uint8)
        temp=cv2.line(temp,(x0P1,y0P1),(x1P1,y1P1), 255, 15)
        
        temp = 255-temp
        
        imgPred=imgPred & temp
        
        h, theta, d = hough_line(imgPred)        
        for _, angle, dist in zip(*hough_line_peaks(h, theta, d,min_distance=9, min_angle=10, threshold=0.5*h.max(), num_peaks=1)):
            y0 = (dist - 0 * np.cos(angle)) / np.sin(angle)
            y1 = (dist - imgPred.shape[1] * np.cos(angle)) / np.sin(angle)
        x0P2 = 0
        y0P2 = int(y0)
        x1P2 = imgPred.shape[1]
        y1P2 = int(y1)
        
        #-------------------------Approximate Line_2------------------------------------------------
        ApproximateLine2=np.zeros_like(imgPred, dtype=np.uint8)
    
        cv2.line(ApproximateLine2,(x0P2,y0P2),(x1P2,y1P2), 255, 1)
        
        ApproximateLine = ApproximateLine2 + ApproximateLine1
        

        cv2.imwrite(midlinesavePath+filename[-13:]+'_Line_1_.png',ApproximateLine1) 
        cv2.imwrite(midlinesavePath+filename[-13:]+'_Line_2_.png',ApproximateLine2) 
        
        
        #-----------------------True Line-1 approximation------------------------------------------
        h, theta, d = hough_line(trueline)        
        for _, angle, dist in zip(*hough_line_peaks(h, theta, d,min_distance=9, min_angle=10, threshold=0.5*h.max(), num_peaks=1)):
            y0 = (dist - 0 * np.cos(angle)) / np.sin(angle)
            y1 = (dist - imgPred.shape[1] * np.cos(angle)) / np.sin(angle)
        x0G1 = 0
        y0G1 = int(y0)
        x1G1= imgPred.shape[1]
        y1G1= int(y1)
        
        up=np.zeros_like(trueline, dtype=np.uint8)
    
        cv2.line(up,(x0G1,y0G1),(x1G1,y1G1), 255, 1)  
        
        temp=np.zeros_like(trueline, dtype=np.uint8)
    
        cv2.line(temp,(x0G1,y0G1),(x1G1,y1G1), 255, 15) 
        temp = 255-temp
        
        trueline= trueline & temp
        
        labelImage=label(trueline)
        regions=regionprops(labelImage)
        Area=[]
        for region in range(len(regions)):
            maxThreshold=regions[region].area,
            Area.append(maxThreshold)
        X= sorted( [(x,i) for (i,x) in enumerate(Area)], reverse=True )[:2]

        index=np.array(X)
        V=index.T[1].tolist()
        trueline[labelImage!=(V[0]+1)]=0
        
        h, theta, d = hough_line(trueline)        
        for _, angle, dist in zip(*hough_line_peaks(h, theta, d,min_distance=9, min_angle=10, threshold=0.5*h.max(), num_peaks=1)):
            y0 = (dist - 0 * np.cos(angle)) / np.sin(angle)
            y1 = (dist - imgPred.shape[1] * np.cos(angle)) / np.sin(angle)
        x0G2 = 0
        y0G2 = int(y0)
        x1G2= imgPred.shape[1]
        y1G2= int(y1)
        
        low=np.zeros_like(trueline, dtype=np.uint8)
    
        cv2.line(low,(x0G2,y0G2),(x1G2,y1G2), 255, 1)   
        
        trueline = up+low

#         savelinePath=midlinesavePath+filename[-13:]+'_ApproxPLUStrue_.png'
#         cv2.imwrite(savelinePath,ApproximateLine+trueline) 
        
        #-------------------Overlay with original Image-------------------------------       
        temp = cv2.merge((ApproximateLine, ApproximateLine, ApproximateLine))
        temp [:,:,0]=0
        temp [:,:,2]=0  
        
        temp1 = cv2.merge((trueline, trueline, trueline))
        temp1 [:,:,0]=0

        
        dummy1 = cv2.addWeighted(temp,0.99,orimg,0.8,0)
        dummy2 = cv2.addWeighted(temp1,0.99,dummy1,0.8,0)
        
#         savelinePath=midlinesavePath+filename[-13:]+'_overlay_.png'
#         cv2.imwrite(savelinePath,dummy2) 
        
        
        AngularDisplacement_approx1_up=Angular_Displacement(height = 192,
                                                            width = 256,
                                                            L1x1 = x0P1,
                                                            L1y1 = y0P1,
                                                            L1x2 = x1P1,
                                                            L1y2 = y1P1,
                                                            L2x1 = x0G1,
                                                            L2y1 = y0G1,
                                                            L2x2 = x1G1,
                                                            L2y2 = y1G1)
        
        AngularDisplacement_approx1_low=Angular_Displacement(height = 192,
                                                            width = 256,
                                                            L1x1 = x0P1,
                                                            L1y1 = y0P1,
                                                            L1x2 = x1P1,
                                                            L1y2 = y1P1,
                                                            L2x1 = x0G2,
                                                            L2y1 = y0G2,
                                                            L2x2 = x1G2,
                                                            L2y2 = y1G2)
        
        AngularDisplacement_approx2_up=Angular_Displacement(height = 192,
                                                            width = 256,
                                                            L1x1 = x0P2,
                                                            L1y1 = y0P2,
                                                            L1x2 = x1P2,
                                                            L1y2 = y1P2,
                                                            L2x1 = x0G1,
                                                            L2y1 = y0G1,
                                                            L2x2 = x1G1,
                                                            L2y2 = y1G1)
        
        AngularDisplacement_approx2_low=Angular_Displacement(height = 192,
                                                            width = 256,
                                                            L1x1 = x0P2,
                                                            L1y1 = y0P2,
                                                            L1x2 = x1P2,
                                                            L1y2 = y1P2,
                                                            L2x1 = x0G2,
                                                            L2y1 = y0G2,
                                                            L2x2 = x1G2,
                                                            L2y2 = y1G2)
        
        if AngularDisplacement_approx1_up>AngularDisplacement_approx1_low:
            line_1_Error = AngularDisplacement_approx1_low
        else:
            line_1_Error = AngularDisplacement_approx1_up
    
        AngularDisplacement_Line_1.append(line_1_Error)
        
        if AngularDisplacement_approx2_up>AngularDisplacement_approx2_low:
            line_2_Error = AngularDisplacement_approx2_low
        else:
            line_2_Error = AngularDisplacement_approx2_up
    
        AngularDisplacement_Line_2.append(line_2_Error)

        Error= (line_1_Error+line_2_Error)/2
        
        bothError.append(Error)
        
        font                   = cv2.FONT_HERSHEY_SIMPLEX
        bottomLeftCornerOfText = (80,185)
        fontScale              = 1
        fontColor              = (255,255,255)
        lineType               = 2

        cv2.putText(dummy2,str(round(degrees(Error),2)), 
            bottomLeftCornerOfText, 
            font, 
            fontScale,
            fontColor,
            lineType)
        savelinePath=midlinesavePath+'ImgID_'+filename[-12:]+'_Pred_True-EdgeLine.png'
        cv2.imwrite(savelinePath,dummy2) 
        
        print('Angular Displacement (AD) in radian: '+ str(Error)
              + '  Angular Displacement (AD) in degrees: ' + str(degrees(Error)))

        
  
print()
print('-----------------------Final mean Angular Displacement (mAD)---------------------------')
print()
print('mAD in radians: '+ str(np.mean(bothError)) + '  mAD in degrees: ' + str(degrees(np.mean(bothError))))
print('std. AD in radians: '+ str(math.sqrt(np.mean((np.array(bothError)-np.mean(bothError))**2))) 
      + '  median AD in radians: ' + str(np.median(bothError)))
# Out:
# Angular Displacement (AD) in radian: 0.0279385291137560  Angular Displacement (AD) in degrees: 1.6007598040215951
# Angular Displacement (AD) in radian: 0.0168614780516564  Angular Displacement (AD) in degrees: 0.9660915287123848
# Angular Displacement (AD) in radian: 0.0519033149317498  Angular Displacement (AD) in degrees: 2.9738408883276097
# Angular Displacement (AD) in radian: 0.0361090711512959  Angular Displacement (AD) in degrees: 2.0688973791068497
# Angular Displacement (AD) in radian: 0.0256499388713313  Angular Displacement (AD) in degrees: 1.4696332420958365
# Angular Displacement (AD) in radian: 0.00886677533916934  Angular Displacement (AD) in degrees: 0.508028804825082
# Angular Displacement (AD) in radian: 0.00886677533916957  Angular Displacement (AD) in degrees: 0.5080288048250956
# Angular Displacement (AD) in radian: 0.0158184453595639  Angular Displacement (AD) in degrees: 0.9063301575613114
# Angular Displacement (AD) in radian: 0.0259585338270951  Angular Displacement (AD) in degrees: 1.4873144306401314
# Angular Displacement (AD) in radian: 0.0151225757524524  Angular Displacement (AD) in degrees: 0.8664597659823974
# Angular Displacement (AD) in radian: 0.0443167955983119  Angular Displacement (AD) in degrees: 2.539165349327216
# Angular Displacement (AD) in radian: 0.0710995504497669  Angular Displacement (AD) in degrees: 4.073704166049118
# Angular Displacement (AD) in radian: 0.0589323572896648  Angular Displacement (AD) in degrees: 3.376575349454822
# Angular Displacement (AD) in radian: 0.154039091408014  Angular Displacement (AD) in degrees: 8.825789817709103
# Angular Displacement (AD) in radian: 0.0437239006614170  Angular Displacement (AD) in degrees: 2.505194971748463
# Angular Displacement (AD) in radian: 0.00884262323661097  Angular Displacement (AD) in degrees: 0.5066449912821206
# Angular Displacement (AD) in radian: 0.00930165694967931  Angular Displacement (AD) in degrees: 0.5329456856951558
# Angular Displacement (AD) in radian: 0.0200838118885284  Angular Displacement (AD) in degrees: 1.1507176577473448
# Angular Displacement (AD) in radian: 0.0104161406804197  Angular Displacement (AD) in degrees: 0.596800899802574
# Angular Displacement (AD) in radian: 0.114656025887018  Angular Displacement (AD) in degrees: 6.5693063790688555
# Angular Displacement (AD) in radian: 0.0241030278907365  Angular Displacement (AD) in degrees: 1.38100177162531
# Angular Displacement (AD) in radian: 0.0297152411763042  Angular Displacement (AD) in degrees: 1.7025579066155894
# Angular Displacement (AD) in radian: 0.0387105758614830  Angular Displacement (AD) in degrees: 2.2179526193839743
# Angular Displacement (AD) in radian: 0.0110339063636394  Angular Displacement (AD) in degrees: 0.6321962661790784
# Angular Displacement (AD) in radian: 0.0163340821032369  Angular Displacement (AD) in degrees: 0.9358739667356463
# Angular Displacement (AD) in radian: 0.0265347514636742  Angular Displacement (AD) in degrees: 1.5203292692971155
# Angular Displacement (AD) in radian: 0.0180427861327257  Angular Displacement (AD) in degrees: 1.033775496062351
# Angular Displacement (AD) in radian: 0.0124228421693260  Angular Displacement (AD) in degrees: 0.7117764258595259
# Angular Displacement (AD) in radian: 0.0313783801934386  Angular Displacement (AD) in degrees: 1.7978487530409264
# Angular Displacement (AD) in radian: 0.0206782541372203  Angular Displacement (AD) in degrees: 1.1847766897616547
# Angular Displacement (AD) in radian: 0.0535324232883003  Angular Displacement (AD) in degrees: 3.0671819215274447
# Angular Displacement (AD) in radian: 0.00273447537196748  Angular Displacement (AD) in degrees: 0.15667389799620238
# Angular Displacement (AD) in radian: 0.0217131260251819  Angular Displacement (AD) in degrees: 1.2440704812785917
# Angular Displacement (AD) in radian: 0.0254652430186452  Angular Displacement (AD) in degrees: 1.459050949243356
# Angular Displacement (AD) in radian: 0.0218393613323594  Angular Displacement (AD) in degrees: 1.2513032316054002
# Angular Displacement (AD) in radian: 0.0163476300991523  Angular Displacement (AD) in degrees: 0.936650209722457
# Angular Displacement (AD) in radian: 0.0141351781837692  Angular Displacement (AD) in degrees: 0.809886052595373
# Angular Displacement (AD) in radian: 0.0414521586700969  Angular Displacement (AD) in degrees: 2.3750337435031748
# Angular Displacement (AD) in radian: 0.0161452295908443  Angular Displacement (AD) in degrees: 0.925053514825105
# Angular Displacement (AD) in radian: 0.0555540999701178  Angular Displacement (AD) in degrees: 3.1830154629356042
# Angular Displacement (AD) in radian: 0.0336599895099528  Angular Displacement (AD) in degrees: 1.9285753373749197
# Angular Displacement (AD) in radian: 0.00958196692506158  Angular Displacement (AD) in degrees: 0.5490062642399758
# Angular Displacement (AD) in radian: 0.0890387867213357  Angular Displacement (AD) in degrees: 5.101546692098014
# Angular Displacement (AD) in radian: 0.0384559409195250  Angular Displacement (AD) in degrees: 2.203363111893224
# Angular Displacement (AD) in radian: 0.163978548601436  Angular Displacement (AD) in degrees: 9.395278765543134
# Angular Displacement (AD) in radian: 0.0561484823767603  Angular Displacement (AD) in degrees: 3.2170710662530477
# Angular Displacement (AD) in radian: 0.00740771495748213  Angular Displacement (AD) in degrees: 0.42443080289965807
# Angular Displacement (AD) in radian: 0.0185622043526621  Angular Displacement (AD) in degrees: 1.0635359678669045
# Angular Displacement (AD) in radian: 0.0452547885316832  Angular Displacement (AD) in degrees: 2.592908385622485
# Angular Displacement (AD) in radian: 0.0205965050219964  Angular Displacement (AD) in degrees: 1.1800928104803963
# Angular Displacement (AD) in radian: 0.0253319475591236  Angular Displacement (AD) in degrees: 1.4514136819845096
# Angular Displacement (AD) in radian: 0.0416677549252729  Angular Displacement (AD) in degrees: 2.3873864990035876
# Angular Displacement (AD) in radian: 0.00328798832319385  Angular Displacement (AD) in degrees: 0.18838785400730415
# Angular Displacement (AD) in radian: 0.0126662739151142  Angular Displacement (AD) in degrees: 0.7257240374926919
# Angular Displacement (AD) in radian: 0.00750351200321229  Angular Displacement (AD) in degrees: 0.4299195693098178
# Angular Displacement (AD) in radian: 0.0201601232200342  Angular Displacement (AD) in degrees: 1.155089974971652
# Angular Displacement (AD) in radian: 0.0301320025116987  Angular Displacement (AD) in degrees: 1.7264365721979327
# Angular Displacement (AD) in radian: 0.00764393381738840  Angular Displacement (AD) in degrees: 0.4379651466136796
# Angular Displacement (AD) in radian: 0.0129457581180833  Angular Displacement (AD) in degrees: 0.7417373027633972
# Angular Displacement (AD) in radian: 0.00884262323661111  Angular Displacement (AD) in degrees: 0.5066449912821287
# Angular Displacement (AD) in radian: 0.0354768890894994  Angular Displacement (AD) in degrees: 2.0326760150820324
# Angular Displacement (AD) in radian: 0.0185961426660243  Angular Displacement (AD) in degrees: 1.0654804899863515
# Angular Displacement (AD) in radian: 0.0249364089162543  Angular Displacement (AD) in degrees: 1.4287509871137638
# Angular Displacement (AD) in radian: 0.0113127999524285  Angular Displacement (AD) in degrees: 0.6481756917499508
# Angular Displacement (AD) in radian: 0.0368416565225457  Angular Displacement (AD) in degrees: 2.1108714290124913
# Angular Displacement (AD) in radian: 0.0870018004676827  Angular Displacement (AD) in degrees: 4.984835976837533
# Angular Displacement (AD) in radian: 0.0875538926610507  Angular Displacement (AD) in degrees: 5.016468529419635
# Angular Displacement (AD) in radian: 0.0266457921957123  Angular Displacement (AD) in degrees: 1.5266914345969445
# Angular Displacement (AD) in radian: 0.0524013258296651  Angular Displacement (AD) in degrees: 3.0023748109296777
# Angular Displacement (AD) in radian: 0.00988331864544728  Angular Displacement (AD) in degrees: 0.566272445967083
# Angular Displacement (AD) in radian: 0.106498579739073  Angular Displacement (AD) in degrees: 6.101919143186337
# Angular Displacement (AD) in radian: 0.0173228241692752  Angular Displacement (AD) in degrees: 0.9925247141466824
# Angular Displacement (AD) in radian: 0.0792745669286464  Angular Displacement (AD) in degrees: 4.54209810773881
# Angular Displacement (AD) in radian: 0.00806625589068716  Angular Displacement (AD) in degrees: 0.46216241900891303
# Angular Displacement (AD) in radian: 0.0206873027662838  Angular Displacement (AD) in degrees: 1.1852951380173744
# Angular Displacement (AD) in radian: 0  Angular Displacement (AD) in degrees: 0.0
# Angular Displacement (AD) in radian: 0.0331568682419337  Angular Displacement (AD) in degrees: 1.8997486121341576
# Angular Displacement (AD) in radian: 0.0440314159081833  Angular Displacement (AD) in degrees: 2.5228142975240964
# Angular Displacement (AD) in radian: 0.00885069437557734  Angular Displacement (AD) in degrees: 0.507107433480757
# Angular Displacement (AD) in radian: 0.0441688588205050  Angular Displacement (AD) in degrees: 2.5306891963241185
# Angular Displacement (AD) in radian: 0.635956279766822  Angular Displacement (AD) in degrees: 36.43761078547991
# Angular Displacement (AD) in radian: 0.0553008637799248  Angular Displacement (AD) in degrees: 3.168506098017571
# Angular Displacement (AD) in radian: 0.0227196223591731  Angular Displacement (AD) in degrees: 1.3017384733116755
# Angular Displacement (AD) in radian: 0.00952044488109392  Angular Displacement (AD) in degrees: 0.5454813107736105
# Angular Displacement (AD) in radian: 0.0191920818764976  Angular Displacement (AD) in degrees: 1.0996252915928293
# Angular Displacement (AD) in radian: 0.0338254187463388  Angular Displacement (AD) in degrees: 1.9380537344279076
# Angular Displacement (AD) in radian: 0.0390221144481910  Angular Displacement (AD) in degrees: 2.2358024655578146
# Angular Displacement (AD) in radian: 0.0189671128029628  Angular Displacement (AD) in degrees: 1.0867355131583156
# Angular Displacement (AD) in radian: 0.00767767657657058  Angular Displacement (AD) in degrees: 0.4398984643039447
# Angular Displacement (AD) in radian: 0  Angular Displacement (AD) in degrees: 0.0
# Angular Displacement (AD) in radian: 0.0312892682848505  Angular Displacement (AD) in degrees: 1.792743016774471
# Angular Displacement (AD) in radian: 0.0432091781391752  Angular Displacement (AD) in degrees: 2.4757035436036765
# Angular Displacement (AD) in radian: 0.00879051749424115  Angular Displacement (AD) in degrees: 0.5036595521559339
# Angular Displacement (AD) in radian: 0.0480029076819075  Angular Displacement (AD) in degrees: 2.7503640145294175
# Angular Displacement (AD) in radian: 0.0268259090232210  Angular Displacement (AD) in degrees: 1.537011368632477
# Angular Displacement (AD) in radian: 0.00852159944248222  Angular Displacement (AD) in degrees: 0.48825168275526626
# Angular Displacement (AD) in radian: 0.0478730410425448  Angular Displacement (AD) in degrees: 2.7429232041943887
# Angular Displacement (AD) in radian: 0.00708423507759160  Angular Displacement (AD) in degrees: 0.4058967710245318
# Angular Displacement (AD) in radian: 0.122165051130898  Angular Displacement (AD) in degrees: 6.999541833800332
# Angular Displacement (AD) in radian: 0.0793233184727329  Angular Displacement (AD) in degrees: 4.5448913654597165
# Angular Displacement (AD) in radian: 0.0704051447642637  Angular Displacement (AD) in degrees: 4.033917650999897
# Angular Displacement (AD) in radian: 0.0497245064789898  Angular Displacement (AD) in degrees: 2.8490043596170342
# Angular Displacement (AD) in radian: 0.0469861161855214  Angular Displacement (AD) in degrees: 2.692106153141703
# Angular Displacement (AD) in radian: 0.0175600300590875  Angular Displacement (AD) in degrees: 1.0061156105085771
# Angular Displacement (AD) in radian: 0.0967470767267332  Angular Displacement (AD) in degrees: 5.543199176670164
# Angular Displacement (AD) in radian: 0.0702546046961587  Angular Displacement (AD) in degrees: 4.0252923404498695
# Angular Displacement (AD) in radian: 0.0298451826313473  Angular Displacement (AD) in degrees: 1.71000300357335
# Angular Displacement (AD) in radian: 0.0620318319149762  Angular Displacement (AD) in degrees: 3.554162164193061
# Angular Displacement (AD) in radian: 0.0627163476680554  Angular Displacement (AD) in degrees: 3.593382027854715
# Angular Displacement (AD) in radian: 0.114253834864526  Angular Displacement (AD) in degrees: 6.546262530921996
# Angular Displacement (AD) in radian: 0.0532138016351729  Angular Displacement (AD) in degrees: 3.048926245541767
# Angular Displacement (AD) in radian: 0.0281051263106060  Angular Displacement (AD) in degrees: 1.6103051202798087
# Angular Displacement (AD) in radian: 0.0510398262112943  Angular Displacement (AD) in degrees: 2.924366628988357
# Angular Displacement (AD) in radian: 0.0421981332844441  Angular Displacement (AD) in degrees: 2.4177749405291715
# Angular Displacement (AD) in radian: 0.0411347262009715  Angular Displacement (AD) in degrees: 2.3568462027418717
# Angular Displacement (AD) in radian: 0.0299916129096450  Angular Displacement (AD) in degrees: 1.7183928405127324
# Angular Displacement (AD) in radian: 0.186164071490847  Angular Displacement (AD) in degrees: 10.666415593397282
# Angular Displacement (AD) in radian: 0.0112926716958081  Angular Displacement (AD) in degrees: 0.6470224275966442
# Angular Displacement (AD) in radian: 0.0361759277801268  Angular Displacement (AD) in degrees: 2.0727279817713375
# Angular Displacement (AD) in radian: 0.0388671863005251  Angular Displacement (AD) in degrees: 2.226925736568782
# Angular Displacement (AD) in radian: 0.0147597056125883  Angular Displacement (AD) in degrees: 0.8456688384568609
# Angular Displacement (AD) in radian: 0.0143446469202792  Angular Displacement (AD) in degrees: 0.8218877271373329
# Angular Displacement (AD) in radian: 0.0270637097123118  Angular Displacement (AD) in degrees: 1.5506363444826798
# Angular Displacement (AD) in radian: 0.0353857236049154  Angular Displacement (AD) in degrees: 2.0274526175781045
# Angular Displacement (AD) in radian: 0.0535903032976529  Angular Displacement (AD) in degrees: 3.070498201781532
# Angular Displacement (AD) in radian: 0.00879072095071354  Angular Displacement (AD) in degrees: 0.5036712093531164
# Angular Displacement (AD) in radian: 0.0261388360365379  Angular Displacement (AD) in degrees: 1.4976449862780872
# Angular Displacement (AD) in radian: 0.0173455944114317  Angular Displacement (AD) in degrees: 0.9938293529207428
# Angular Displacement (AD) in radian: 0.0343671794528632  Angular Displacement (AD) in degrees: 1.9690943364177838
# Angular Displacement (AD) in radian: 0.0175222329534368  Angular Displacement (AD) in degrees: 1.0039499958769822
# Angular Displacement (AD) in radian: 0.0882344960894261  Angular Displacement (AD) in degrees: 5.055464233387683
# Angular Displacement (AD) in radian: 0.0436692000041727  Angular Displacement (AD) in degrees: 2.5020608549517718
# Angular Displacement (AD) in radian: 0.0961122190997118  Angular Displacement (AD) in degrees: 5.50682451405015
# Angular Displacement (AD) in radian: 0.0529121001153629  Angular Displacement (AD) in degrees: 3.03164002178397
# Angular Displacement (AD) in radian: 0.0103922568820685  Angular Displacement (AD) in degrees: 0.5954324589583085
# Angular Displacement (AD) in radian: 0.0697414756356622  Angular Displacement (AD) in degrees: 3.995892210937906
# Angular Displacement (AD) in radian: 0.0106758697968225  Angular Displacement (AD) in degrees: 0.611682281989119
# Angular Displacement (AD) in radian: 0.0655016746676512  Angular Displacement (AD) in degrees: 3.75296950949539
# Angular Displacement (AD) in radian: 0.0529940175837494  Angular Displacement (AD) in degrees: 3.0363335469909143
# Angular Displacement (AD) in radian: 0.336207691993073  Angular Displacement (AD) in degrees: 19.26328179103739
# Angular Displacement (AD) in radian: 0.0208015996631944  Angular Displacement (AD) in degrees: 1.191843867821794
# Angular Displacement (AD) in radian: 0.0208013852294174  Angular Displacement (AD) in degrees: 1.191831581671389
# Angular Displacement (AD) in radian: 0.0438709146375211  Angular Displacement (AD) in degrees: 2.513618252108665
# Angular Displacement (AD) in radian: 0.0113188609038164  Angular Displacement (AD) in degrees: 0.6485229586843136
# Angular Displacement (AD) in radian: 0.0270790117374459  Angular Displacement (AD) in degrees: 1.551513085940869
# Angular Displacement (AD) in radian: 0.0343496174058722  Angular Displacement (AD) in degrees: 1.96808810524559
# Angular Displacement (AD) in radian: 0.00891049913077693  Angular Displacement (AD) in degrees: 0.5105339935485068
# Angular Displacement (AD) in radian: 0.0526819311981768  Angular Displacement (AD) in degrees: 3.018452314254109
# Angular Displacement (AD) in radian: 0.0350840566883136  Angular Displacement (AD) in degrees: 2.010168376438096
# Angular Displacement (AD) in radian: 0.0532189451364156  Angular Displacement (AD) in degrees: 3.0492209464548927
# Angular Displacement (AD) in radian: 0.00313343158009520  Angular Displacement (AD) in degrees: 0.1795324049324639
# Angular Displacement (AD) in radian: 0.0448015887424350  Angular Displacement (AD) in degrees: 2.5669419504223483
# Angular Displacement (AD) in radian: 0.0371878387333187  Angular Displacement (AD) in degrees: 2.1307062086322914
# Angular Displacement (AD) in radian: 0.0460829372789981  Angular Displacement (AD) in degrees: 2.6403578136526757
#
# -----------------------Final mean Angular Displacement (mAD)---------------------------
#
# mAD in radians: 0.0427987082979580  mAD in degrees: 2.452185354084531
# std. AD in radians: 0.06199938307393123  median AD in radians: 0.0297802119038258

# %% [markdown]
# ## Evaluations of Detection Sub-network

# %%
PostivePrediction = np.array(np.loadtxt('labelPos.csv'))
NegativePrediction = np.array(np.loadtxt('labelNeg.csv'))
PredictedLabel = np.concatenate((PostivePrediction, NegativePrediction), axis=0)

# %%
truePositivelabel = np.array(np.ones((NegativePrediction.shape), dtype='float64'))
trueNegativelabel = np.array(np.zeros((NegativePrediction.shape), dtype='float64'))
trueLabel = np.concatenate((truePositivelabel, trueNegativelabel), axis=0)

# %%
precision = precision_score(trueLabel, PredictedLabel, average='macro') 
accuracy = accuracy_score(trueLabel, PredictedLabel, normalize=True)
fpr, tpr, thresholds = roc_curve(trueLabel, PredictedLabel)
AUC = auc(fpr, tpr)

# %%
print()
print('--------------Final Detection sub-network performances are as follows:--------------------')
print("Precision = %0.4f" % (precision*100))
print("Accuracy = %0.4f" % (accuracy*100))
print("Area Under ROC curve = %0.4f" % (AUC))
# Out:
# --------------Final Detection sub-network performances are as follows:--------------------
# Precision = 100.0000
# Accuracy = 100.0000
# Area Under ROC curve = 1.0000
